# %%
a = [1, 2, 3, 4, 5] # リストの作成
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[0]
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %%
a[4] = 99 # 値を代入
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[1:]
# Out:
# [2, 3, 4, 99]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[:-1] # 最初から最後の要素一つ前まで取得
# Out:
# [1, 2, 3, 4]

# %%
a[:-2] # 最初から最後の要素の2つ前まで取得
# Out:
# [1, 2, 3]
